# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
num=input("Enter your institute name ? :")
# Out:
# Enter your institute name ? : AAMEC

# %%
Name= input("Enter your name :")
Age =input("Enter your age:")
schoolname=input("Enter your school name :")
degree =input("Enter your degree :")
# Out:
# Enter your name : divya
# Enter your age: 34
# Enter your school name : shwartz
# Enter your degree : B.Tech IT

# %%
a=43
b=34
print("a=",a,"\nb=",b,"\nadd=",a+b)
# Out:
# a= 43
# b= 34
# add= 77

# %%
a=43
b=34
print("a=",a,"\nb=",b,"\nsub=",a-b)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
a=63
b=97
print("a=",a,"\nb=",b,"\nMul=",a*b)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
a=76
b=31
print("a=",a,"\nb=",b,"\nFloat Div=",a/b)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
a=76
b=31
print("a=",a,"\nb=",b,"\nFloat Div=",round(a/b))
# Out:
# a= 76
# b= 31
# Float Div= 2

# %%
a=76
b=31
print("a=",a,"\nb=",b,"\nFloat Div=",a%b)
# Out:
# a= 76
# b= 31
# Float Div= 14

# %%
a=4
b=4
print("a=",a,"\nb=",b,"\npower=",a**b)
# Out:
# a= 4
# b= 4
# power= 256
