# %%
Num1= 10
Num2= 20
Add= Num1+Num2
print("Add=",Add)
# Out:
# Add= 30

# %%
print("Overall Employee Salary :")
Arun =10000
Sweetha =20000
print("Arun=",Arun)
print("Swetha=",Sweetha)
print("Total Salary in office=",Arun+Sweetha)
# Out:
# Overall Employee Salary :
# Arun= 10000
# Swetha= 20000
# Total Salary in office= 30000

# %%
num= int(input("Enter your DOB:"))
# Out:
# Enter your DOB: 512

# %%
num='hi'
print(num)
# Out:
# hi
