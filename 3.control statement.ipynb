# %%
if():
    print()

# %%
num = int(input("enter the age:"))
# Out:
# enter the age: 16

# %%
if (num==18):
      print("Adult")

# %%
age =int(input("Enter your age:"))
# Out:
# Enter your age: 30

# %%
if (age<18):
    print("Children")
else :
    print("Adult")
# Out:
# Adult

# %%
Bno =int(input("Enter your building no:"))
# Out:
# Enter your building no: 3

# %%
if (Bno<3):
    print("1st Block")
elif(Bno<6):
    print("2nd Block")
elif(Bno<9):
    print("3rd Block")
else :
    print("4th Block")
# Out:
# 2nd Block

# %%
lists=[2,4,7]

# %%
for bno in lists:
    if (Bno<3):
        print("1st Block")
    elif(Bno<6):
        print("2nd Block")
    elif(Bno<9):
        print("3rd Block")
    else :
        print("4th Block")
# Out:
# 2nd Block
# 2nd Block
# 2nd Block
